# %%
import pandas as pd
import numpy as np

# %%
import os
import glob

path = '.'
extension = 'csv'
os.chdir(path)
new_datahunts_csvs = glob.glob('*.{}'.format(extension))

# %%
new_datahunts_df = {}
for csv in new_datahunts_csvs:
    new_datahunts_df[csv] = pd.read_csv(csv)

# %%
pd.concat(new_datahunts_df)
# Out:
#                                                             namespace  \
# Covid_Evidencev1-Task-2226-DataHunt.csv 0    Covid_Evidence2020_03_21
#                                         1    Covid_Evidence2020_03_21
#                                         2    Covid_Evidence2020_03_21
#                                         3    Covid_Evidence2020_03_21
#                                         4    Covid_Evidence2020_03_21
# ...                                                               ...
# Covid_Evidencev1-Task-2224-DataHunt.csv 768  Covid_Evidence2020_03_21
#                                         769  Covid_Evidence2020_03_21
#                                         770  Covid_Evidence2020_03_21
#                                         771  Covid_Evidence2020_03_21
#                                         772  Covid_Evidence2020_03_21
#
#                                                                                  schema_sha256  \
# ...

# %%
new_datahunts_df[new_datahunts_csvs[0]]
# Out:
#                    namespace  \
# 0   Covid_Evidence2020_03_21
# 1   Covid_Evidence2020_03_21
# 2   Covid_Evidence2020_03_21
# 3   Covid_Evidence2020_03_21
# 4   Covid_Evidence2020_03_21
# 5   Covid_Evidence2020_03_21
# 6   Covid_Evidence2020_03_21
# 7   Covid_Evidence2020_03_21
# 8   Covid_Evidence2020_03_21
# 9   Covid_Evidence2020_03_21
# 10  Covid_Evidence2020_03_21
# 11  Covid_Evidence2020_03_21
# 12  Covid_Evidence2020_03_21
# 13  Covid_Evidence2020_03_21
# 14  Covid_Evidence2020_03_21
# 15  Covid_Evidence2020_03_21
# 16  Covid_Evidence2020_03_21
# 17  Covid_Evidence2020_03_21
# 18  Covid_Evidence2020_03_21
# 19  Covid_Evidence2020_03_21
# 20  Covid_Evidence2020_03_21
# 21  Covid_Evidence2020_03_21
# 22  Covid_Evidence2020_03_21
# 23  Covid_Evidence2020_03_21
# 24  Covid_Evidence2020_03_21
# 25  Covid_Evidence2020_03_21
# 26  Covid_Evidence2020_03_21
# 27  Covid_Evidence2020_03_21
# 28  Covid_Evidence2020_03_21
# 29  Covid_Evidence2020_03_21
# 30  Covid_Evidence2020_03_21
# ...

# %%
# Don't run this cell more than once. Restart kernel if needed.
path = '../'
extension = 'csv'
os.chdir(path)
old_datahunts_csvs = glob.glob('*.{}'.format(extension))
print(old_datahunts_csvs)
# Out:
# []
